# %% [markdown]
# <a href="https://colab.research.google.com/github/mishukovaanna/lab/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#найти массу
# Дано
import numpy as np
import matplotlib.pyplot as plt
T=np.linspace(0,400,100) # Кельвин
P=101325 # Паскаль
V=64 #м^3
R=8.314
# Решение 1
M=0.016
m=(P*V*M)/(R*T) # Фунция
plt.plot(T,m) # линейный график
plt.show()
#
# Out:
# <ipython-input-2-0964950099a3>:11: RuntimeWarning: divide by zero encountered in true_divide
#   m=(P*V*M)/(R*T) # Фунция

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 42.3 MB/s eta 0:00:00
# ...

# %%
# Решение 2
import CoolProp.CoolProp as ct
import numpy as np
import matplotlib.pyplot as plt
fluid_name="water"
t=np.linspace(274,600,100)
p=101325
V=64
M=0.016
d=ct.PropsSI("D","T",t,"P",p,fluid_name)
m=d*V
plt.plot(t,m,"r")
plt.title("grafik")
plt.xlabel("temperatura")
plt.ylabel("piotnost")
plt.grid()

T=np.linspace(0,400,100)
R=8.314
m=(P*V*M)/(R*T)
plt.plot(T,m)
plt.scatter(373.15,45.92,color="b")
plt.show()
# Out:
# <ipython-input-17-999a4877bc7b>:20: RuntimeWarning: divide by zero encountered in true_divide
#   m=(P*V*M)/(R*T)
